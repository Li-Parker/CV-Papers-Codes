# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# 读取图像
image_path = r"./translated_data/binary_mask/8210028813_1d192a3fa1_k.png"
image = plt.imread(image_path)

# image = np.array(Image.open(image_path))[:,:,1]
print(np.max(image))
print(image.shape)

# 显示图像
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 0.02745098
# (1152, 2048)
